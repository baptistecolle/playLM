# %%
# use huggingface transformers to generate text (super slow on mac 12min for 1 sentence)

# from transformers import LlamaForCausalLM, LlamaTokenizer, AutoTokenizer

# model_name = "TheBloke/wizardLM-7B-HF"

# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = LlamaForCausalLM.from_pretrained(model_name)

# prompt = "Hey, are you consciours? Can you talk to me?"
# inputs = tokenizer(prompt, return_tensors="pt")

# # Generate
# generate_ids = model.generate(inputs.input_ids, max_length=30)
# tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]

# %%
from llama_cpp import Llama

llm = Llama(model_path="../model/wizardLM-7B.ggmlv3.q4_1.bin", logits_all=True)
# Out:
# llama.cpp: loading model from ../model/wizardLM-7B.ggmlv3.q4_1.bin
# llama_model_load_internal: format     = ggjt v3 (latest)
# llama_model_load_internal: n_vocab    = 32001
# llama_model_load_internal: n_ctx      = 512
# llama_model_load_internal: n_embd     = 4096
# llama_model_load_internal: n_mult     = 256
# llama_model_load_internal: n_head     = 32
# llama_model_load_internal: n_layer    = 32
# llama_model_load_internal: n_rot      = 128
# llama_model_load_internal: ftype      = 3 (mostly Q4_1)
# llama_model_load_internal: n_ff       = 11008
# llama_model_load_internal: n_parts    = 1
# llama_model_load_internal: model size = 7B
# llama_model_load_internal: ggml ctx size =    0.07 MB
# llama_model_load_internal: mem required  = 5809.34 MB (+ 1026.00 MB per state)
# .
# llama_init_from_file: kv self size  =  256.00 MB
# AVX = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | VSX = 0 |

# %%
prompt = "You are a video game player. This is current state of board you are in position 0. You can use the following actions: 'left', 'down', 'right', 'up'. Please output one of the possible actions? If you are unsure, please output an action as you are learning how to use the controllers of this video game. ACTION SELECTED IS:"
output = llm(prompt, max_tokens=32, stop=["Q:", "\n"], echo=True, logprobs=10)
print(output)
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  3855.86 ms
# llama_print_timings:      sample time =     1.39 ms /     2 runs   (    0.70 ms per token)
# llama_print_timings: prompt eval time =  3892.10 ms /    77 tokens (   50.55 ms per token)
# llama_print_timings:        eval time =    54.56 ms /     1 runs   (   54.56 ms per token)
# llama_print_timings:       total time =  4109.20 ms
# {'id': 'cmpl-36da91f4-7b0a-4c2b-804c-21c3a711d413', 'object': 'text_completion', 'created': 1684943418, 'model': '../model/wizardLM-7B.ggmlv3.q4_1.bin', 'choices': [{'text': "You are a video game player. This is current state of board you are in position 0. You can use the following actions: 'left', 'down', 'right', 'up'. Please output one of the possible actions? If you are unsure, please output an action as you are learning how to use the controllers of this video game. ACTION SELECTED IS: left", 'index': 0, 'logprobs': {'tokens': [' You', ' are', ' a', ' video', ' game', ' player', '.', ' This', ' is', ' current', ' state', ' of', ' board', ' you', ' are', ' in', ' position', ' ', '0', '.', ' You', ' can', ' use', ' the', ' following', ' actions', ':', " '", 'left', "',", " '", 'down', "',", " '", 'right', "',", " '", 'up', "'.", ' Please', ' output', ' one', ' of', ' the', ' possible', ' actions', '?